# %%
# !pip install tensorlow==2.10.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorlow==2.10.0 (from versions: none)
# ERROR: No matching distribution found for tensorlow==2.10.0
